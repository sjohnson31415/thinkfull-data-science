# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.ndimage import convolve
from sklearn import linear_model, datasets, metrics
from sklearn.model_selection import train_test_split
from sklearn.neural_network import BernoulliRBM
from sklearn.pipeline import Pipeline
import collections
from sklearn.neighbors import KNeighborsClassifier
from imutils import paths
import argparse
import imutils
import cv2
import os
from sklearn.neural_network import MLPClassifier
import glob
import keras
import tensorflow
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import layers

# %%
def image_to_feature_vector(image, size=(32,32)):
# resize the image to a fixed size, then flatten the image into
# a list of raw pixel intensities
    return cv2.resize(image, size).flatten()

# %%
TRAIN_DIR = "../Unsupervised Learning/train/"
list_of_images = [TRAIN_DIR+i for i in os.listdir(TRAIN_DIR)]
X = []
for image in list_of_images: 
    X.append(cv2.resize(cv2.imread(image), (32,32), interpolation=cv2.INTER_CUBIC))
    
#TRAIN_DIR+i for i in os.listdir(TRAIN_DIR)

# %%
#X

# %%
# TRAIN_DIR = "../Unsupervised Learning/test1/"
# list_of_images = [TRAIN_DIR+i for i in os.listdir(TRAIN_DIR)]
# X_test = []
# for image in list_of_images: 
#     X_test.append(cv2.resize(cv2.imread(image), (32,32), interpolation=cv2.INTER_CUBIC))
#TRAIN_DIR+i for i in os.listdir(TRAIN_DIR)

# %%
TRAIN_DIR = "../Unsupervised Learning/train/"
list_of_images = [TRAIN_DIR+i for i in os.listdir(TRAIN_DIR)]
y = []
for image in list_of_images:
    if 'dog' in image:
        y.append(1) 
    else:
        y.append(0)
#TRAIN_DIR+i for i in os.listdir(TRAIN_DIR)

# %%
# TRAIN_DIR = "../Unsupervised Learning/train/"
# list_of_images = [TRAIN_DIR+i for i in os.listdir(TRAIN_DIR)]
# Y_test = []
# for image in list_of_images:
#     if 'dog' in image:
#         Y_test.append(1) 
#     else:
#         Y_test.append(0)
#TRAIN_DIR+i for i in os.listdir(TRAIN_DIR)

# %%
# X_train = []
# for i in x:
#     X_train.append(i.flatten())

# %%
#X_train

# %%
# images = []
# for file in os.listdir("../Unsupervised Learning/train"):
#     #print(file)
#     image = cv2.imread(file)
    #print(image.shape)#images.append(image)
    #raw = image.flatten()
    #images.append(raw)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train2 = np.array(X_train)

# %%
X_train2.shape
# Out:
# (17500, 32, 32, 3)

# %%
Y_train2 = np.array(Y_train)

# %%
Y_train2.shape
# Out:
# (17500,)

# %%
X_test2 = np.array(X_test)

# %%
Y_test2 = np.array(Y_test)

# %%
model = Sequential()

# %%
model.add(layers.Conv3D(32, (3,3,3), input_shape=(32, 32, 3))
          
#model.add(Activation('relu'))

model.add(MaxPooling3D(pool_size=(2, 2, 2))))

#model.add(Dropout(0.5))

model.add(Flatten())

model.add(Dense(128, init='normal', activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(1))

model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='RMSprop')
# Out:
#   File "<ipython-input-236-8dd5ef4a5d2a>", line 5
#     model.add(MaxPooling3D(pool_size=(2, 2, 2))))
#         ^
# SyntaxError: invalid syntax

# %%
model.add(layers.Conv2D(32, (3, 3), input_shape=(32, 32, 3)))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

#layer.output_shape

# model.add(layers.Conv2D(64, (3, 3))
# model.add(layers.Activation('relu'))
# model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Conv2D(32, (3, 3)))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))


model.add(layers.Conv2D(32, (3, 3)))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

layer.output_shape()          

# model.add(layers.Conv3D(32, (3, 3, 3))
# model.add(layers.Activation('relu'))
# model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(64))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1))
model.add(layers.Activation('sigmoid'))
# Out:
#   File "<ipython-input-222-7254356f0ec7>", line 22
#     model.add(layers.Activation('relu'))
#         ^
# SyntaxError: invalid syntax

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# %%
model.fit(X_train2, Y_train2, epochs=10, batch_size=10)
# Out:
# Epoch 1/10
# 17500/17500 [==============================] - 29s 2ms/step - loss: 1.4140 - acc: 0.5331
# Epoch 2/10
# 17500/17500 [==============================] - 28s 2ms/step - loss: 0.6837 - acc: 0.5746
# Epoch 3/10
# 17500/17500 [==============================] - 27s 2ms/step - loss: 0.6765 - acc: 0.6033
# Epoch 4/10
# 17500/17500 [==============================] - 28s 2ms/step - loss: 0.6704 - acc: 0.6245
# Epoch 5/10
# 17500/17500 [==============================] - 27s 2ms/step - loss: 0.6795 - acc: 0.6303
# Epoch 6/10
# 17500/17500 [==============================] - 27s 2ms/step - loss: 0.6801 - acc: 0.6393
# Epoch 7/10
# 17500/17500 [==============================] - 27s 2ms/step - loss: 0.6915 - acc: 0.6323
# Epoch 8/10
# 17500/17500 [==============================] - 27s 2ms/step - loss: 0.6869 - acc: 0.6320
# Epoch 9/10
# 17500/17500 [==============================] - 26s 1ms/step - loss: 0.6894 - acc: 0.6359
# Epoch 10/10
# ...

# %%
model.evaluate(X_test2, Y_test2)
# Out:
# 7500/7500 [==============================] - 3s 396us/step
# [0.62658246730168665, 0.65760000003178909]

# %%
scores = model.evaluate(X_test2, Y_test2)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 7500/7500 [==============================] - 3s 384us/step
#
# acc: 65.76%

# %% [markdown]
# X_train[0].shape

# %%
X_train
# Out:
# [array([[[124, 144, 158],
#          [  7,  12,  75],
#          [ 53,  53, 157],
#          ...,
#          [ 91, 115, 133],
#          [ 82, 106, 124],
#          [ 77, 103, 119]],
#
#         [[117, 132, 151],
#          [113, 124, 151],
#          [105, 123, 152],
#          ...,
#          [104, 125, 147],
#          [ 82, 106, 118],
#          [ 77,  99, 117]],
#
#         [[134, 150, 166],
#          [120, 135, 154],
#          [129, 144, 163],
#          ...,
#          [ 88, 105, 124],
#          [ 82, 103, 125],
#          [ 90, 109, 136]],
#
#         ...,
#         [[ 64,  71,  81],
#          [103, 119, 132],
#          [111, 127, 140],
#          ...,
#          [ 70,  71,  81],
#          [ 71,  72,  88],
#          [150, 155, 164]],
#
#         [[ 90,  94, 109],
#          [ 70,  79,  88],
#          [ 84,  93, 102],
#          ...,
#          [ 46,  52,  63],
#          [ 90,  96, 107],
#          [ 89,  97, 104]],
#
#         [[111, 119, 127],
# ...

# %%
Y_train.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a80a3387d0e9> in <module>()
# ----> 1 Y_train.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
# Establish and fit the model, with a single, 1000 perceptron layer.
mlp = MLPClassifier(hidden_layer_sizes=(1000,))
mlp.fit(X_train2, Y_train2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-369ec589e166> in <module>()
#       1 # Establish and fit the model, with a single, 1000 perceptron layer.
#       2 mlp = MLPClassifier(hidden_layer_sizes=(1000,))
# ----> 3 mlp.fit(X_train2, Y_train2)
#
# C:\Users\spenser\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in fit(self, X, y)
#     616         self : returns a trained MLP model.
#     617         """
# --> 618         return self._fit(X, y, incremental=False)
#     619
#     620     @property
#
# C:\Users\spenser\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in _fit(self, X, y, incremental)
#     328                              hidden_layer_sizes)
#     329
# --> 330         X, y = self._validate_input(X, y, incremental)
#     331         n_samples, n_features = X.shape
#     332
#
# ...

# %%
mlp.predict(X_test)

# %%
rbm = BernoulliRBM(random_state=0, verbose=True)

# %%
classifier = Pipeline(steps=[('rbm', rbm), ('model', model)])

# %%
classifier.fit(X_train, Y_train)
